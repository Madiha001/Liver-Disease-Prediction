# %%
#Import Python Libraries
import numpy as np
# import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# import statsmodels.api as sm
from sklearn import preprocessing

# %%
dat = pd.read_csv("Indian Liver Patient Dataset (ILPD).csv")
dat
# Out:
#      Age  Gender  Total Bilirubin  ...  Albumin  Albumin and Globulin Ratio  Class
# 0     65  Female              0.7  ...      3.3                        0.90      1
# 1     62    Male             10.9  ...      3.2                        0.74      1
# 2     62    Male              7.3  ...      3.3                        0.89      1
# 3     58    Male              1.0  ...      3.4                        1.00      1
# 4     72    Male              3.9  ...      2.4                        0.40      1
# ..   ...     ...              ...  ...      ...                         ...    ...
# 578   60    Male              0.5  ...      1.6                        0.37      2
# 579   40    Male              0.6  ...      3.2                        1.10      1
# 580   52    Male              0.8  ...      3.2                        1.00      1
# 581   31    Male              1.3  ...      3.4                        1.00      1
# ...

# %%
lablEncodr = preprocessing.LabelEncoder()
dataset = dat
dataset['Gender']=lablEncodr.fit_transform(dataset['Gender'])
ds=dataset.dropna() 
y = ds["Class"].values
X = ds.iloc[: , :10]
X
# Out:
#      Age  Gender  ...  Albumin  Albumin and Globulin Ratio
# 0     65       0  ...      3.3                        0.90
# 1     62       1  ...      3.2                        0.74
# 2     62       1  ...      3.3                        0.89
# 3     58       1  ...      3.4                        1.00
# 4     72       1  ...      2.4                        0.40
# ..   ...     ...  ...      ...                         ...
# 578   60       1  ...      1.6                        0.37
# 579   40       1  ...      3.2                        1.10
# 580   52       1  ...      3.2                        1.00
# 581   31       1  ...      3.4                        1.00
# 582   38       1  ...      4.4                        1.50
#
# [579 rows x 10 columns]

# %%
#Results Before Preprocessing of Data
#Applying KNN classifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test,y_pred)
print('Confusion Matrix : \n', cm)
print("Accuracy of KNN for 25-75%: {0:.2}".format(metrics.accuracy_score(y_test, y_pred)))

total=sum(sum(cm))
sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity :{0:.2}'.format(sensitivity))

specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : {0:.2}'.format(specificity))

print('MCC: {0:.2}'.format(metrics.matthews_corrcoef(y_test,y_pred)))
print("F-Measure: {0:.2}".format(metrics.f1_score(y_test,y_pred)))
print('AUROC: {0:.2}'.format(metrics.roc_auc_score(y_test, y_pred)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.82      0.71      0.76       112
#            2       0.33      0.48      0.39        33
#
#     accuracy                           0.66       145
#    macro avg       0.57      0.60      0.57       145
# weighted avg       0.71      0.66      0.68       145
#
# Confusion Matrix :
#  [[79 33]
#  [17 16]]
# Accuracy of KNN for 25-75%: 0.66
# Sensitivity :0.71
# Specificity : 0.48
# MCC: 0.17
# F-Measure: 0.76
# AUROC: 0.6

# %%
#Visualiaztion of Data

# %%
dat.boxplot(column='Age', return_type='axes');

# %%
dat.boxplot(column='Total Bilirubin', return_type='axes');

# %%
dat.boxplot(column='Direct Bilirubin', return_type='axes');

# %%
dat.boxplot(column='Alkphos Alkaline Phosphotase', return_type='axes');

# %%
dat.boxplot(column='Sgpt Alamine Aminotransferase', return_type='axes');

# %%
dat.boxplot(column='Sgot Aspartate Aminotransferase', return_type='axes');

# %%
dat.boxplot(column='Total Protiens', return_type='axes');

# %%
dat.boxplot(column='Albumin', return_type='axes');

# %%
dat.boxplot(column='Albumin and Globulin Ratio', return_type='axes');

# %%
plt.hist(dat['Class'],bins=3)
plt.xlabel("Liver Patient or not")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(dat['Gender'],bins=3)
plt.xlabel("Gender")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sb.boxplot(x='Class',y='Age', data=dat)

# %%
sb.boxplot(x='Gender',y='Age', data=dat)

# %%
sb.scatterplot(x='Age',y='Total Protiens', data=dat)

# %%
sb.scatterplot(x='Class',y='Total Protiens', data=dat)

# %%
sb.scatterplot(x='Age',y='Albumin and Globulin Ratio', data=dat)

# %%
sb.scatterplot(x='Class',y='Albumin and Globulin Ratio', data=dat)

# %%
sb.scatterplot(x='Age',y='Direct Bilirubin', data=dat)

# %%
sb.scatterplot(x='Class',y='Direct Bilirubin', data=dat)

# %%
sb.scatterplot(x='Class',y='Alkphos Alkaline Phosphotase', data=dat)

# %%
sb.scatterplot(x='Age',y='Alkphos Alkaline Phosphotase', data=dat)

# %%
sb.scatterplot(x='Class',y='Sgpt Alamine Aminotransferase', data=dat)

# %%
sb.scatterplot(x='Age',y='Sgpt Alamine Aminotransferase', data=dat)

# %%
sb.scatterplot(x='Class',y='Sgot Aspartate Aminotransferase', data=dat)

# %%
sb.scatterplot(x='Age',y='Sgot Aspartate Aminotransferase', data=dat)

# %%
sb.scatterplot(x='Class',y='Albumin', data=dat)

# %%
sb.scatterplot(x='Age',y='Albumin', data=dat)

# %% [markdown]
# PreProcessing

# %%
dat
# Out:
#      Age  Gender  Total Bilirubin  ...  Albumin  Albumin and Globulin Ratio  Class
# 0     65  Female              0.7  ...      3.3                        0.90      1
# 1     62    Male             10.9  ...      3.2                        0.74      1
# 2     62    Male              7.3  ...      3.3                        0.89      1
# 3     58    Male              1.0  ...      3.4                        1.00      1
# 4     72    Male              3.9  ...      2.4                        0.40      1
# ..   ...     ...              ...  ...      ...                         ...    ...
# 578   60    Male              0.5  ...      1.6                        0.37      2
# 579   40    Male              0.6  ...      3.2                        1.10      1
# 580   52    Male              0.8  ...      3.2                        1.00      1
# 581   31    Male              1.3  ...      3.4                        1.00      1
# ...

# %%
dat.describe()
# Out:
#               Age  Total Bilirubin  ...  Albumin and Globulin Ratio       Class
# count  583.000000       583.000000  ...                  579.000000  583.000000
# mean    44.746141         3.298799  ...                    0.947064    1.286449
# std     16.189833         6.209522  ...                    0.319592    0.452490
# min      4.000000         0.400000  ...                    0.300000    1.000000
# 25%     33.000000         0.800000  ...                    0.700000    1.000000
# 50%     45.000000         1.000000  ...                    0.930000    1.000000
# 75%     58.000000         2.600000  ...                    1.100000    2.000000
# max     90.000000        75.000000  ...                    2.800000    2.000000
#
# [8 rows x 10 columns]

# %%
#Conversion of Nominal Attribute to Discrete
lablEncodr = preprocessing.LabelEncoder()
dataset = dat
dataset['Gender']=lablEncodr.fit_transform(dataset['Gender'])
dataset
# Out:
#      Age  Gender  Total Bilirubin  ...  Albumin  Albumin and Globulin Ratio  Class
# 0     65       0              0.7  ...      3.3                        0.90      1
# 1     62       1             10.9  ...      3.2                        0.74      1
# 2     62       1              7.3  ...      3.3                        0.89      1
# 3     58       1              1.0  ...      3.4                        1.00      1
# 4     72       1              3.9  ...      2.4                        0.40      1
# ..   ...     ...              ...  ...      ...                         ...    ...
# 578   60       1              0.5  ...      1.6                        0.37      2
# 579   40       1              0.6  ...      3.2                        1.10      1
# 580   52       1              0.8  ...      3.2                        1.00      1
# 581   31       1              1.3  ...      3.4                        1.00      1
# ...

# %%
#print column with empty values
dataset[dataset.isnull().any(axis=1)]
# Out:
#      Age  Gender  Total Bilirubin  ...  Albumin  Albumin and Globulin Ratio  Class
# 209   45       0              0.9  ...      3.9                         NaN      1
# 241   51       1              0.8  ...      3.1                         NaN      1
# 253   35       0              0.6  ...      2.7                         NaN      2
# 312   27       1              1.3  ...      4.8                         NaN      2
#
# [4 rows x 11 columns]

# %%
#Filling the missing values with zeros
dataset =dataset.fillna(dataset.mean()['Albumin and Globulin Ratio'])
#checking if still there are any missing values of any attribute
dataset[dataset.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Total Bilirubin, Direct Bilirubin, Alkphos Alkaline Phosphotase, Sgpt Alamine Aminotransferase, Sgot Aspartate Aminotransferase, Total Protiens, Albumin, Albumin and Globulin Ratio, Class]
# Index: []

# %%
dataset.describe()
# Out:
#               Age      Gender  ...  Albumin and Globulin Ratio       Class
# count  583.000000  583.000000  ...                  583.000000  583.000000
# mean    44.746141    0.756432  ...                    0.947064    1.286449
# std     16.189833    0.429603  ...                    0.318492    0.452490
# min      4.000000    0.000000  ...                    0.300000    1.000000
# 25%     33.000000    1.000000  ...                    0.700000    1.000000
# 50%     45.000000    1.000000  ...                    0.947064    1.000000
# 75%     58.000000    1.000000  ...                    1.100000    2.000000
# max     90.000000    1.000000  ...                    2.800000    2.000000
#
# [8 rows x 11 columns]

# %%
#dropping empty rows if there were any
dat=dataset.dropna()
dat
# Out:
#      Age  Gender  Total Bilirubin  ...  Albumin  Albumin and Globulin Ratio  Class
# 0     65       0              0.7  ...      3.3                        0.90      1
# 1     62       1             10.9  ...      3.2                        0.74      1
# 2     62       1              7.3  ...      3.3                        0.89      1
# 3     58       1              1.0  ...      3.4                        1.00      1
# 4     72       1              3.9  ...      2.4                        0.40      1
# ..   ...     ...              ...  ...      ...                         ...    ...
# 578   60       1              0.5  ...      1.6                        0.37      2
# 579   40       1              0.6  ...      3.2                        1.10      1
# 580   52       1              0.8  ...      3.2                        1.00      1
# 581   31       1              1.3  ...      3.4                        1.00      1
# ...

# %%
y = dat["Class"].values
X = dat.iloc[: , :10]
X
#Results After Cleaning of Data
#Applying KNN classifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test,y_pred)
print('Confusion Matrix : \n', cm)
print("Accuracy of KNN for 25-75%: {0:.2}".format(metrics.accuracy_score(y_test, y_pred)))

total=sum(sum(cm))
sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity :{0:.2}'.format(sensitivity))

specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : {0:.2}'.format(specificity))

print('MCC: {0:.2}'.format(metrics.matthews_corrcoef(y_test,y_pred)))
print("F-Measure: {0:.2}".format(metrics.f1_score(y_test,y_pred)))
print('AUROC: {0:.2}'.format(metrics.roc_auc_score(y_test, y_pred)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.79      0.79       106
#            2       0.42      0.40      0.41        40
#
#     accuracy                           0.68       146
#    macro avg       0.60      0.60      0.60       146
# weighted avg       0.68      0.68      0.68       146
#
# Confusion Matrix :
#  [[84 22]
#  [24 16]]
# Accuracy of KNN for 25-75%: 0.68
# Sensitivity :0.79
# Specificity : 0.4
# MCC: 0.2
# F-Measure: 0.79
# AUROC: 0.6

# %%
def outlier_identification(Col):
    lower_range = []
    upper_range = []
    sorted(Col)
    Q1, Q3 = np.percentile(Col , [25,75])
    IQR = Q3 - Q1
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range, upper_range

# %%
#finding min max values in Age column
lower,upper = outlier_identification(dataset['Age'])
print(lower)
print(upper)
#printing outliers
dataset[(dataset['Age']< lower) | (dataset['Age'] > upper)]
# Out:
# -4.5
# 95.5
# Empty DataFrame
# Columns: [Age, Gender, Total Bilirubin, Direct Bilirubin, Alkphos Alkaline Phosphotase, Sgpt Alamine Aminotransferase, Sgot Aspartate Aminotransferase, Total Protiens, Albumin, Albumin and Globulin Ratio, Class]
# Index: []

# %%
#finding min max values in Age column
lower,upper = outlier_identification(dataset['Total Bilirubin'])
print(lower)
print(upper)
#printing outliers
dataset[(dataset['Total Bilirubin']< lower) | (dataset['Total Bilirubin'] > upper)]
# Out:
# -1.9000000000000001
# 5.300000000000001
#      Age  Gender  Total Bilirubin  ...  Albumin  Albumin and Globulin Ratio  Class
# 1     62       1             10.9  ...      3.2                        0.74      1
# 2     62       1              7.3  ...      3.3                        0.89      1
# 22    62       1              6.8  ...      3.1                        0.90      1
# 27    34       1              6.2  ...      4.0                        1.20      1
# 37    46       0             14.2  ...      2.0                        0.80      1
# ..   ...     ...              ...  ...      ...                         ...    ...
# 572   32       1             15.6  ...      4.0                        2.50      1
# 574   32       1             12.1  ...      2.4                        0.50      1
# 575   32       1             25.0  ...      2.5                        2.50      1
# 576   32       1             15.0  ...      2.2                        0.70      1
# ...

# %%
#removing outliers
dataset.drop(dataset[ (dataset['Total Bilirubin'] < lower) | (dataset['Total Bilirubin'] > upper) ].index , inplace=True)
dataset[(dataset['Total Bilirubin']< lower) | (dataset['Total Bilirubin'] > upper)]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Total Bilirubin, Direct Bilirubin, Alkphos Alkaline Phosphotase, Sgpt Alamine Aminotransferase, Sgot Aspartate Aminotransferase, Total Protiens, Albumin, Albumin and Globulin Ratio, Class]
# Index: []

# %%
y = dataset["Class"].values
X = dataset.iloc[: , :10]
X
#Results Before Preprocessing of Data
#Applying KNN classifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test,y_pred)
print('Confusion Matrix : \n', cm)
print("Accuracy of KNN for 25-75%: {0:.2}".format(metrics.accuracy_score(y_test, y_pred)))

total=sum(sum(cm))
sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity :{0:.2}'.format(sensitivity))

specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : {0:.2}'.format(specificity))

print('MCC: {0:.2}'.format(metrics.matthews_corrcoef(y_test,y_pred)))
print("F-Measure: {0:.2}".format(metrics.f1_score(y_test,y_pred)))
print('AUROC: {0:.2}'.format(metrics.roc_auc_score(y_test, y_pred)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.69      0.79      0.74        81
#            2       0.47      0.34      0.39        44
#
#     accuracy                           0.63       125
#    macro avg       0.58      0.57      0.57       125
# weighted avg       0.61      0.63      0.62       125
#
# Confusion Matrix :
#  [[64 17]
#  [29 15]]
# Accuracy of KNN for 25-75%: 0.63
# Sensitivity :0.79
# Specificity : 0.34
# MCC: 0.14
# F-Measure: 0.74
# AUROC: 0.57

# %% [markdown]
# Outlier removal is not improving model's performance so we are using dataset without outlier removal

# %%
#shuffle the data
from sklearn.utils import shuffle
df = shuffle(dat)
df
# Out:
#      Age  Gender  Total Bilirubin  ...  Albumin  Albumin and Globulin Ratio  Class
# 191   60       1              5.8  ...      3.5                        1.12      1
# 502   42       1              0.8  ...      2.7                        1.20      1
# 35    30       1              1.3  ...      3.3                        0.90      1
# 393   41       1              2.7  ...      4.0                        1.00      1
# 232   50       1              2.7  ...      3.1                        0.60      1
# ..   ...     ...              ...  ...      ...                         ...    ...
# 526   46       1              9.4  ...      2.8                        0.80      1
# 359   69       0              0.8  ...      4.9                        1.40      2
# 363   42       0              0.9  ...      4.4                        1.00      2
# 164   39       1              1.9  ...      4.3                        1.38      1
# ...

# %%
y = df["Class"].values
X = df.iloc[: , :10]
X
# Out:
#      Age  Gender  ...  Albumin  Albumin and Globulin Ratio
# 191   60       1  ...      3.5                        1.12
# 502   42       1  ...      2.7                        1.20
# 35    30       1  ...      3.3                        0.90
# 393   41       1  ...      4.0                        1.00
# 232   50       1  ...      3.1                        0.60
# ..   ...     ...  ...      ...                         ...
# 526   46       1  ...      2.8                        0.80
# 359   69       0  ...      4.9                        1.40
# 363   42       0  ...      4.4                        1.00
# 164   39       1  ...      4.3                        1.38
# 256   50       1  ...      3.5                        1.20
#
# [583 rows x 10 columns]

# %%
#Normalization
from sklearn.preprocessing import MinMaxScaler
norm = MinMaxScaler()
X = norm.fit_transform(X)

#Standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[ 0.94299664,  0.56744644,  0.40314676, ...,  0.10770625,
#          0.45059283,  0.54345047],
#        [-0.16976697,  0.56744644, -0.4027597 , ..., -1.45980724,
#         -0.55590379,  0.7948499 ],
#        [-0.91160937,  0.56744644, -0.32216906, ...,  0.38432628,
#          0.19896867, -0.14789798],
#        ...,
#        [-0.16976697, -1.76228085, -0.38664157, ...,  1.85963311,
#          1.58290153,  0.16635131],
#        [-0.35522757,  0.56744644, -0.22546028, ...,  0.84535967,
#          1.45708945,  1.36049863],
#        [ 0.32479464,  0.56744644, -0.38664157, ..., -0.26112045,
#          0.45059283,  0.7948499 ]])

# %%
#Results After Shuffling, Standardization, Normalization of Data
#Applying KNN classifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test,y_pred)
print('Confusion Matrix : \n', cm)
print("Accuracy of KNN for 25-75%: {0:.2}".format(metrics.accuracy_score(y_test, y_pred)))

total=sum(sum(cm))
sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity :{0:.2}'.format(sensitivity))

specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : {0:.2}'.format(specificity))

print('MCC: {0:.2}'.format(metrics.matthews_corrcoef(y_test,y_pred)))
print("F-Measure: {0:.2}".format(metrics.f1_score(y_test,y_pred)))
print('AUROC: {0:.2}'.format(metrics.roc_auc_score(y_test, y_pred)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.79      0.80      0.80       111
#            2       0.35      0.34      0.35        35
#
#     accuracy                           0.69       146
#    macro avg       0.57      0.57      0.57       146
# weighted avg       0.69      0.69      0.69       146
#
# Confusion Matrix :
#  [[89 22]
#  [23 12]]
# Accuracy of KNN for 25-75%: 0.69
# Sensitivity :0.8
# Specificity : 0.34
# MCC: 0.15
# F-Measure: 0.8
# AUROC: 0.57

# %%
#Feature Extraction
def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold) and (corr_matrix.columns[j] not in col_corr):
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
                if colname in dataset.columns:
                    del dataset[colname] # deleting the column from the dataset

    print(dataset)
correlation(df,0.7)
# Out:
#      Age  Gender  ...  Albumin and Globulin Ratio  Class
# 191   60       1  ...                        1.12      1
# 502   42       1  ...                        1.20      1
# 35    30       1  ...                        0.90      1
# 393   41       1  ...                        1.00      1
# 232   50       1  ...                        0.60      1
# ..   ...     ...  ...                         ...    ...
# 526   46       1  ...                        0.80      1
# 359   69       0  ...                        1.40      2
# 363   42       0  ...                        1.00      2
# 164   39       1  ...                        1.38      1
# 256   50       1  ...                        1.20      1
#
# [583 rows x 8 columns]

# %%
y = df["Class"].values
X = df.iloc[: , :7]
X

#Normalization
from sklearn.preprocessing import MinMaxScaler
norm = MinMaxScaler()
X = norm.fit_transform(X)

#Standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
X

#SMOTE
from imblearn.over_sampling import SMOTE
print("Before OverSampling, counts of label '2': {}".format(sum(y_train==2)))
print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))

sm = SMOTE(random_state=2)
X_train_res, y_train_res = sm.fit_resample(X, y.ravel())

print("After OverSampling, counts of label '2': {}".format(sum(y_train_res==2)))
print("After OverSampling, counts of label '1': {}".format(sum(y_train_res==1)))

print('Before OverSampling, the shape of train_X: {}'.format(X_train.shape))
print('Before OverSampling, the shape of train_y: {} \n'.format(y_train.shape))

print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(X_train_res, y_train_res, test_size=0.25)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test,y_pred)
print('Confusion Matrix : \n', cm)
print("Accuracy of KNN for 25-75%: {0:.2}".format(metrics.accuracy_score(y_test, y_pred)))

total=sum(sum(cm))
sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity :{0:.2}'.format(sensitivity))

specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : {0:.2}'.format(specificity))

print('MCC: {0:.2}'.format(metrics.matthews_corrcoef(y_test,y_pred)))
print("F-Measure: {0:.2}".format(metrics.f1_score(y_test,y_pred)))
print('AUROC: {0:.2}'.format(metrics.roc_auc_score(y_test, y_pred)))
# Out:
# Before OverSampling, counts of label '2': 309
# Before OverSampling, counts of label '1': 315
# After OverSampling, counts of label '2': 416
# After OverSampling, counts of label '1': 416
# Before OverSampling, the shape of train_X: (624, 7)
# Before OverSampling, the shape of train_y: (624,)
#
# After OverSampling, the shape of train_X: (832, 7)
# After OverSampling, the shape of train_y: (832,)
#
#               precision    recall  f1-score   support
#
#            1       0.78      0.58      0.66       107
#            2       0.65      0.82      0.72       101
#
#     accuracy                           0.70       208
#    macro avg       0.71      0.70      0.69       208
# weighted avg       0.71      0.70      0.69       208
#
# Confusion Matrix :
#  [[62 45]
#  [18 83]]
# Accuracy of KNN for 25-75%: 0.7
# Sensitivity :0.58
# Specificity : 0.82
# MCC: 0.41
# F-Measure: 0.66
# AUROC: 0.7

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_res, y_train_res, test_size=0.25)

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test,y_pred)
print('Confusion Matrix : \n', cm)
print("Accuracy of KNN for 25-75%: {0:.2}".format(metrics.accuracy_score(y_test, y_pred)))

total=sum(sum(cm))
sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity :{0:.2}'.format(sensitivity))

specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : {0:.2}'.format(specificity))

print('MCC: {0:.2}'.format(metrics.matthews_corrcoef(y_test,y_pred)))
print("F-Measure: {0:.2}".format(metrics.f1_score(y_test,y_pred)))
print('AUROC: {0:.2}'.format(metrics.roc_auc_score(y_test, y_pred)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.79      0.66      0.72        94
#            2       0.75      0.86      0.80       114
#
#     accuracy                           0.77       208
#    macro avg       0.77      0.76      0.76       208
# weighted avg       0.77      0.77      0.77       208
#
# Confusion Matrix :
#  [[62 32]
#  [16 98]]
# Accuracy of KNN for 25-75%: 0.77
# Sensitivity :0.66
# Specificity : 0.86
# MCC: 0.53
# F-Measure: 0.72
# AUROC: 0.76
